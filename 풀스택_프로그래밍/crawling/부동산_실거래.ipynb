# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "http://openapi.seoul.go.kr:8088/6a694e435965686437356f555a4d49/xml/tbLnOpendataRtmsV/1/5/"
req = requests.get(url)
#print(req.text)
soup = BeautifulSoup(req.text, "lxml")

ACC_YEAR = soup.find_all("stddate")
SGG_CD = soup.find_all("SGG_CD")
SGG_NM = soup.find_all("SGG_NM")
BJDONG_CD = soup.find_all("BJDONG_CD")
BJDONG_NM = soup.find_all("BJDONG_NM")
LAND_GBN = soup.find_all("LAND_GBN")
LAND_GBN_NM = soup.find_all("LAND_GBN_NM")
BONBEON = soup.find_all("BONBEON")
BUBEON = soup.find_all("BUBEON")
BLDG_NM = soup.find_all("BLDG_NM")
DEAL_YMD = soup.find_all("DEAL_YMD")
OBJ_AMT = soup.find_all("OBJ_AMT")
BLDG_AREA = soup.find_all("BLDG_AREA")
TOT_AREA = soup.find_all("TOT_AREA")
FLOOR = soup.find_all("FLOOR")
RIGHT_GBN = soup.find_all("RIGHT_GBN")
CNTL_YMD = soup.find_all("CNTL_YMD")

ACC_YEAR = []
SGG_CD = []
SGG_NM = []
BJDONG_CD = []
BJDONG_NM = []
LAND_GBN = []
LAND_GBN_NM = []
BONBEON = []
BUBEON = []
BLDG_NM = []
DEAL_YMD = []
OBJ_AMT = []
BLDG_AREA = []
TOT_AREA = []
FLOOR = []
RIGHT_GBN = []
CNTL_YMD = []

for ACC_YEAR, SGG_CD, SGG_NM, BJDONG_CD, BJDONG_NM, LAND_GBN, LAND_GBN_NM, BONBEON, BUBEON, BLDG_NM, DEAL_YMD, OBJ_AMT, BLDG_AREA, TOT_AREA, FLOOR, RIGHT_GBN, CNTL_YMD in zip(ACC_YEAR, SGG_CD, SGG_NM, BJDONG_CD, BJDONG_NM, LAND_GBN, LAND_GBN_NM, BONBEON, BUBEON, BLDG_NM, DEAL_YMD, OBJ_AMT, BLDG_AREA, TOT_AREA, FLOOR, RIGHT_GBN, CNTL_YMD):
    #print(date.get_text(), timeAvg.get_text())
    stddate.append(date.get_text())
    avgTime.append(timeAvg.get_text())
    ACC_YEAR.append(ACC_YEAR.get_text())
    SGG_CD.append(SGG_CD.get_text())
    SGG_NM.append(SGG_NM.get_text())
    BJDONG_CD.append(BJDONG_CD.get_text())
    BJDONG_NM.append(BJDONG_NM.get_text())
    LAND_GBN.append(LAND_GBN.get_text())
    LAND_GBN_NM.append(LAND_GBN_NM.get_text())
    BONBEON.append(BONBEON.get_text())
    BUBEON.append(BUBEON.get_text())
    BLDG_NM.append(BLDG_NM.get_text())
    DEAL_YMD.append(DEAL_YMD.get_text())
    OBJ_AMT.append(OBJ_AMT.get_text())
    BLDG_AREA.append(BLDG_AREA.get_text())
    TOT_AREA.append(TOT_AREA.get_text())
    FLOOR.append(FLOOR.get_text())
    RIGHT_GBN.append(RIGHT_GBN.get_text())
    CNTL_YMD.append(CNTL_YMD.get_text())

df = pd.DataFrame({"ACC_YEAR" : ACC_YEAR, "SGG_CD" : SGG_CD, "SGG_NM" : SGG_NM, "BJDONG_CD" : BJDONG_CD, "BJDONG_NM" : BJDONG_NM, "LAND_GBN" : LAND_GBN, "LAND_GBN_NM" : LAND_GBN_NM, "BONBEON" : BONBEON, "BUBEON" : BUBEON, "BLDG_NM" : BLDG_NM, "DEAL_YMD" : DEAL_YMD, "OBJ_AMT" : OBJ_AMT, "BLDG_AREA" : BLDG_AREA, "TOT_AREA" : TOT_AREA, "FLOOR" : FLOOR, "RIGHT_GBN" : RIGHT_GBN, "CNTL_YMD" : CNTL_YMD})
df
# Out:
# Empty DataFrame
# Columns: [ACC_YEAR, SGG_CD, SGG_NM, BJDONG_CD, BJDONG_NM, LAND_GBN, LAND_GBN_NM, BONBEON, BUBEON, BLDG_NM, DEAL_YMD, OBJ_AMT, BLDG_AREA, TOT_AREA, FLOOR, RIGHT_GBN, CNTL_YMD]
# Index: []

# %%
import requests
import pandas as pd 

serviceKey = 'vnzCfWb%2FXrw%2BgVQ9vQMuV7pZ9G2lzv9am4p%2F88ViesNQZXex8w9aKwH%2FSUQG7amqiiX2SgjSgLkaGew870pjDg%3D%3D'
pageNo = 1 # 페이지 번호
numOfRows = 1000 # 한 페이지 결과수
LAWD_CD = 11560 # 지역코드
DEAL_YMD = 202307 # 계약월
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey={serviceKey}&pageNo={pageNo}&numOfRows=10&LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}'
req = requests.get(url)
req.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    41,700</거래금액><거래유형>중개거래</거래유형><건축년도>2020</건축년도><년>2023</년><도로명>경인로</도로명><도로명건물본번호코드>00900</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>00</도로명일련번호코드><도로명코드>3000028</도로명코드><등기일자> </등기일자><법정동> 영등포동1가</법정동><법정동본번코드>0094</법정동본번코드><법정동부번코드>0002</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10200</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>여의도더리브스타일</아파트><월>7</월><일>1</일><일련번호>11560-2153</일련번호><전용면적>30.2696</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>94-2</지번><지역코드>11560</지역코드><층>3</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    30,500</거래금액><거래유형>직거래</거래유형><건축년도>2022</건축년도><년>2023</년><도로명>경인로114길</도로명><도로명건물본번호코드>00006</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>00</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154044</도로명코드><등기일자>23.08.01</등기일자><법정동> 영등포동1가</
# ...

# %%
# !pip install xmltodict
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xmltodict
import json

# %%
data_dict = xmltodict.parse(req.text)
data_dict
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'거래금액': '41,700',
#       '거래유형': '중개거래',
#       '건축년도': '2020',
#       '년': '2023',
#       '도로명': '경인로',
#       '도로명건물본번호코드': '00900',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '00',
#       '도로명코드': '3000028',
#       '등기일자': None,
#       '법정동': '영등포동1가',
#       '법정동본번코드': '0094',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '여의도더리브스타일',
#       '월': '7',
#       '일': '1',
#       '일련번호': '11560-2153',
#       '전용면적': '30.2696',
#       '중개사소재지': '서울 영등포구',
#       '지번': '94-2',
#       '지역코드': '11560',
#       '층': '3',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '30,500',
#       '거래유형': '직거래',
#       '건축년도': '2022',
#       '년': '2023',
#       '도로명': '경인로114길',
#       '도로명건물본번호코드': '00006',
#       '도로명건물부번호코드': '00000',
# ...

# %%
# %%timeit

import xmltodict
import pandas as pd

data_dict = xmltodict.parse(req.text)
pd.DataFrame(data_dict['response']['body']['items']['item'])
# Out:
# 1.92 ms ± 79.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## 서울 열린데이터 광장

# %%
import requests
import json
import pandas as pd
SERVICE_KEY = '564b7852646a686a34336f4f6c5571'

# %%
data = None

for i in range(1, 13):
    url = f'http://openapi.seoul.go.kr:8088/{SERVICE_KEY}/json/tbLnOpendataRtmsV/{1+(i-1)*1000}/{i * 1000}/2023/11560'
    print(url)
    req = requests.get(url)
    content = req.json()
    con = content['tbLnOpendataRtmsV']['row']
    result = pd.DataFrame(con)
    data = pd.concat([data, result])

data = data.reset_index(drop=True)
data.head()
# Out:
# http://openapi.seoul.go.kr:8088/564b7852646a686a34336f4f6c5571/json/tbLnOpendataRtmsV/1/1000/2023/11560
# http://openapi.seoul.go.kr:8088/564b7852646a686a34336f4f6c5571/json/tbLnOpendataRtmsV/1001/2000/2023/11560
# http://openapi.seoul.go.kr:8088/564b7852646a686a34336f4f6c5571/json/tbLnOpendataRtmsV/2001/3000/2023/11560
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 8
#       6 req = requests.get(url)
#       7 content = req.json()
# ----> 8 con = content['tbLnOpendataRtmsV']['row']
#       9 result = pd.DataFrame(con)
#      10 data = pd.concat([data, result])
#
# KeyError: 'tbLnOpendataRtmsV'
